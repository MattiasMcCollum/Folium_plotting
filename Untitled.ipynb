# %% [markdown]
# # Choropleth plotting

# %% [markdown]
# An example notebook to familiarise myself with and experiment with some of Foliums choropleth plotting capabilities

# %% [markdown]
# To start out, use foliums basic `Map` method which takes Latitude and longitude and plots a basic GPS map, complete with labels and scrollable action
# The Map function also offers the option to change the tiling format (it will default to the OpenStreemMap format, that used by the likes of Google Maps and Apple Maps)
#
# We can also save this to a html document to be sharable

# %%
import folium

# %%
map_types = ['Stamen Terrain', 'Stamen Toner', 'Cartodb Positron']

boston = folium.Map(location=[42.36114, -71.05708], tiles=map_types[0], zoom_start=10)
boston

#boston.save('bostom_map.html')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_20a88ffe2110e96ebe72ccd3191f05c5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_20a88ffe2110e96ebe72ccd3191f05c5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_20a88ffe2110e96ebe72ccd3191f05c5 = L.map(
#                 &quot;map_20a88ffe2110e96ebe72ccd3191f05c5&quot;,
#                 {
#                     center: [42.36114, -71.05708],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a3c1ac2b39016b176230c627391a249f = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_20a88ffe2110e96ebe72ccd3191f05c5);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Foliums map structure works much like a layering system, where we can define features and add them to the base map layer. A good example would be markers for specifying specific coordinates

# %%
boston = folium.Map(location=[42.36114, -71.05708], tiles=map_types[0], zoom_start=10)

folium.Marker([42.3769, -71.0606], popup='<i>Bunker Hill</i>', tooltip="Bunker Hill Monument", icon=folium.Icon(color='red', icon='landmark', prefix='fa')).add_to(boston)
folium.Marker([42.3569, -71.0656], popup='<i>Boston Common</i>', tooltip="Boston Common", icon=folium.Icon(color='blue', icon='tree', prefix='fa')).add_to(boston)
folium.Marker([42.3615, -71.0580], popup='<i>Boston City Hall</i>', tooltip="Boston City Hall", icon=folium.Icon(color='green', icon='city', prefix='fa')).add_to(boston)
folium.Marker([42.3398, -71.0939], popup='<i>Boston Museum of Fine Art</i>', tooltip="Museum of Fine Art", icon=folium.Icon(color='red', icon='museum', prefix='fa')).add_to(boston)


boston
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8c3c0ac52549ec7033f401fc58d63a8f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8c3c0ac52549ec7033f401fc58d63a8f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8c3c0ac52549ec7033f401fc58d63a8f = L.map(
#                 &quot;map_8c3c0ac52549ec7033f401fc58d63a8f&quot;,
#                 {
#                     center: [42.36114, -71.05708],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b38b417401664ff700b797645a60a7c3 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8c3c0ac52549ec7033f401fc58d63a8f);
#
#
#             var marker_5748914f9ea4b8c0707a236aa710d8be = L.marker(
#                 [42.3769, -71.0606],
#                 {}
#             ).addTo(map_8c3c0ac52549ec7033f401fc58d63a8f);
#
#
#             var icon_1c530bcaf9ee9dcdf2c51ab6b5309113 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;landmark&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_5748914f9ea4b8c0707a236aa710d8be.setIcon(icon_1c530bcaf9ee9dcdf2c51ab6b5309113);
#
#
#         var popup_1d842c32d8571c059ffaace8bbdc7ecd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_620f0d58f6e50df5c84c3b0e63a2ba5f = $(`&lt;div id=&quot;html_620f0d58f6e50df5c84c3b0e63a2ba5f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;Bunker Hill&lt;/i&gt;&lt;/div&gt;`)[0];
#                 popup_1d842c32d8571c059ffaace8bbdc7ecd.setContent(html_620f0d58f6e50df5c84c3b0e63a2ba5f);
#
#
#
#         marker_5748914f9ea4b8c0707a236aa710d8be.bindPopup(popup_1d842c32d8571c059ffaace8bbdc7ecd)
#         ;
#
#
#
#
#             marker_5748914f9ea4b8c0707a236aa710d8be.bindTooltip(
#                 `&lt;div&gt;
#                      Bunker Hill Monument
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ed9830ddad1a88cdf8826e8a50f44bca = L.marker(
#                 [42.3569, -71.0656],
#                 {}
#             ).addTo(map_8c3c0ac52549ec7033f401fc58d63a8f);
#
#
#             var icon_46afd5b1ee83de37e4bfa04f00ab4c2b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;tree&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_ed9830ddad1a88cdf8826e8a50f44bca.setIcon(icon_46afd5b1ee83de37e4bfa04f00ab4c2b);
#
#
#         var popup_f9c7b45bc7e61251bc14ecedbdbf461d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d637c49f9643ad2fa7357f88a82d8cf4 = $(`&lt;div id=&quot;html_d637c49f9643ad2fa7357f88a82d8cf4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;Boston Common&lt;/i&gt;&lt;/div&gt;`)[0];
#                 popup_f9c7b45bc7e61251bc14ecedbdbf461d.setContent(html_d637c49f9643ad2fa7357f88a82d8cf4);
#
#
#
#         marker_ed9830ddad1a88cdf8826e8a50f44bca.bindPopup(popup_f9c7b45bc7e61251bc14ecedbdbf461d)
#         ;
#
#
#
#
#             marker_ed9830ddad1a88cdf8826e8a50f44bca.bindTooltip(
#                 `&lt;div&gt;
#                      Boston Common
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_787f8e78c589423002fbcc25d895cc60 = L.marker(
#                 [42.3615, -71.058],
#                 {}
#             ).addTo(map_8c3c0ac52549ec7033f401fc58d63a8f);
#
#
#             var icon_256bbca4ebe3b69ec0d624afa25dfda5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;city&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_787f8e78c589423002fbcc25d895cc60.setIcon(icon_256bbca4ebe3b69ec0d624afa25dfda5);
#
#
#         var popup_1c027c3452b173ba1de32f7f1fc23dff = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_92777a7b591be06d54f0f8012528be79 = $(`&lt;div id=&quot;html_92777a7
